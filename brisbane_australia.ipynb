# %%
from bs4 import BeautifulSoup
import selenium
from selenium.common.exceptions import TimeoutException
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, WebDriverException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://rentberry.com/au/apartments/s/brisbane-qld-australia')
time.sleep(2)

# %%
consent = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/button[3]')
consent.click()

# %%
Rent_url = []
start = 0
end = 15
for page in range (start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    for i in url:
        Rent_url.append(i.get_attribute('href'))
    
    Next_button = driver.find_elements(By.XPATH, '//span[@class="pagination-arrow-next"]')
    time.sleep(3)

# %%
print(len(Rent_url))
# Out:
# 330

# %%
Bed = []
Bath = []
Area = []
Price = []
Pets = []
Address =[]
Deposit = []
AC  = []
Dishwasher = []
Storage = []

# %%
for url in Rent_url:
    driver.get(url)
    delay = 3
    
    try:
        bed = driver.find_element(By.XPATH, '//*[@id="main-info"]/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[1]/div[2]/span[1]')
        Bed.append(bed.text)
    except NoSuchElementException:
        Bed.append('Null')
    except StaleElementReferenceException:
        Bed.append('Null')
    except WebDriverException:
        Bed.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        bath = driver.find_element(By.XPATH, '//span[@class="bathrooms"]')
        Bath.append(bath.text)
    except NoSuchElementException:
        Bath.append('Null')
    except StaleElementReferenceException:
        Bath.append('Null')
    except WebDriverException:
        Bath.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        area = driver.find_element(By.XPATH, '//div[@class="internals-item"][3]/div[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('Null')
    except StaleElementReferenceException:
        Area.append('Null')
    except WebDriverException:
        Area.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        price = driver.find_element(By.XPATH, '//div[@class="property-card-bottom-price"]/p')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Null')
    except StaleElementReferenceException:
        price.append('Null')
    except WebDriverException:
        price.append('Null')  
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        ac = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li[1]/div/span[2]')
        AC.append(ac.text)
    except NoSuchElementException:
        AC.append('Null')
    except WebDriverException:
        AC.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)

    try:
        dishwasher = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li[4]/div/span[2]')
        Dishwasher.append(dishwasher.text)
    except NoSuchElementException:
        Dishwasher.append('Null')
    except WebDriverException:
        Dishwasher.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except StaleElementReferenceException:
        Dishwasher.append('Null')

    
    try:
        address = driver.find_element(By.XPATH, '//span[@class="property-data-address-name"]')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Address.append('Null')
    except StaleElementReferenceException:
        Address.append('Null')
        
    try:
        pets = driver.find_element(By.XPATH, '//*[@id="main-info"]/section/div/div/rb-property-facilities/section/div[4]/span[2]')
        Pets.append(pets.text)
    except NoSuchElementException:
        Pets.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Pets.append('Null')
    except StaleElementReferenceException:
        Pets.append('Null')

# %%
DF5 = pd.DataFrame({'Address':Address,'Bed':Bed,'Bath':Bath,'Area':Area,'Pets':Pets,'Dishwasher':Dishwasher,'AC':AC,'Price':Price})
DF5
# Out:
#                                                Address     Bed  Bath  \
# 0                       Park Ridge QLD 4125, Australia      3     2
# 1                             Lota QLD 4179, Australia      2     2
# 2                           Woorim QLD 4507, Australia      2     2
# 3                     Kelvin Grove QLD 4059, Australia      2     2
# 4    Banksia Beach, City of Moreton Bay, Greater Br...      1     1
# ..                                                 ...     ...   ...
# 325                   Saint Lucia, Brisbane, Australia      5     5
# 326                     Logan City QLD 4118, Australia      5     3
# 327  Auchenflower, Auchenflower Terrace, Auchenflow...      1     3
# 328                  Brisbane City QLD 4178, Australia  Studio  Null
# 329                  Brisbane City QLD 4068, Australia      2     1
#
#               Area     Pets  Dishwasher                AC    Price
# 0    4,348 \nSq Ft  No pets  Dishwasher  Air Conditioning   $5,771
# 1      969 \nSq Ft  No pets        Null  Air Conditioning   $3,437
# 2             Null     Null  Dishwasher  Air Conditioning   $5,431
# 3       11 \nSq Ft  No pets     Parking  Air Conditioning   $5,686
# 4             Null     Null        Null  Air Conditioning   $3,649
# ..             ...      ...         ...               ...      ...
# 325           Null     Null        Null  Air Conditioning     Null
# 326  4,392 \nSq Ft     Dogs      Garden  Air Conditioning  $13,366
# 327           Null     Cats  Dishwasher  Air Conditioning   $4,328
# 328           Null     Null        Null  Air Conditioning   $3,395
# 329  1,959 \nSq Ft  No pets        Null  Air Conditioning   $8,147
#
# [330 rows x 8 columns]

# %%
import time
import csv

# %%
csv_file_path = 'DF5.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file_path:
    csv_writer = csv.writer(csv_file_path)

# %%
import joblib
joblib.dump(DF5,'df5')
# Out:
# ['df5']

# %%
New_Data_Scraped2 =  joblib.load('df5')
New_Data_Scraped2
# Out:
#                                                Address     Bed  Bath  \
# 0                       Park Ridge QLD 4125, Australia      3     2
# 1                             Lota QLD 4179, Australia      2     2
# 2                           Woorim QLD 4507, Australia      2     2
# 3                     Kelvin Grove QLD 4059, Australia      2     2
# 4    Banksia Beach, City of Moreton Bay, Greater Br...      1     1
# ..                                                 ...     ...   ...
# 325                   Saint Lucia, Brisbane, Australia      5     5
# 326                     Logan City QLD 4118, Australia      5     3
# 327  Auchenflower, Auchenflower Terrace, Auchenflow...      1     3
# 328                  Brisbane City QLD 4178, Australia  Studio  Null
# 329                  Brisbane City QLD 4068, Australia      2     1
#
#               Area     Pets  Dishwasher                AC    Price
# 0    4,348 \nSq Ft  No pets  Dishwasher  Air Conditioning   $5,771
# 1      969 \nSq Ft  No pets        Null  Air Conditioning   $3,437
# 2             Null     Null  Dishwasher  Air Conditioning   $5,431
# 3       11 \nSq Ft  No pets     Parking  Air Conditioning   $5,686
# 4             Null     Null        Null  Air Conditioning   $3,649
# ..             ...      ...         ...               ...      ...
# 325           Null     Null        Null  Air Conditioning     Null
# 326  4,392 \nSq Ft     Dogs      Garden  Air Conditioning  $13,366
# 327           Null     Cats  Dishwasher  Air Conditioning   $4,328
# 328           Null     Null        Null  Air Conditioning   $3,395
# 329  1,959 \nSq Ft  No pets        Null  Air Conditioning   $8,147
#
# [330 rows x 8 columns]

# %%
New_Data_Scraped2.to_excel("df5.xlsx", index = True, header = True)
print('spreadsheet saved :')
# Out:
# spreadsheet saved :

# %%
driver.close()
