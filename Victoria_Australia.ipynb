# %%
from bs4 import BeautifulSoup
import selenium
from selenium.common.exceptions import TimeoutException
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, WebDriverException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://rentberry.com/au/apartments/s/brisbane-qld-australia')
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8720\3114788961.py in <module>
# ----> 1 driver.get('https://rentberry.com/au/apartments/s/brisbane-qld-australia')
#       2 time.sleep(2)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     351     def get(self, url: str) -> None:
#     352         """Loads a web page in the current browser session."""
# --> 353         self.execute(Command.GET, {"url": url})
#     354
#     355     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=121.0.6167.141)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79E615E42+3538674]
# 	(No symbol) [0x00007FF79E234C02]
# 	(No symbol) [0x00007FF79E0E5AEB]
# 	(No symbol) [0x00007FF79E0C288C]
# 	(No symbol) [0x00007FF79E155DD7]
# 	(No symbol) [0x00007FF79E16B40F]
# 	(No symbol) [0x00007FF79E14EE53]
# 	(No symbol) [0x00007FF79E11F514]
# 	(No symbol) [0x00007FF79E120631]
# 	GetHandleVerifier [0x00007FF79E646CAD+3738973]
# 	GetHandleVerifier [0x00007FF79E69C506+4089270]
# 	GetHandleVerifier [0x00007FF79E694823+4057299]
# 	GetHandleVerifier [0x00007FF79E365C49+720121]
# 	(No symbol) [0x00007FF79E24126F]
# 	(No symbol) [0x00007FF79E23C304]
# 	(No symbol) [0x00007FF79E23C432]
# 	(No symbol) [0x00007FF79E22BD04]
# 	BaseThreadInitThunk [0x00007FFC791A257D+29]
# 	RtlUserThreadStart [0x00007FFC7ABEAA58+40]

# %%
consent = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/button[3]')
consent.click()

# %%
Rent_url = []
start = 0
end = 15
for page in range (start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    for i in url:
        Rent_url.append(i.get_attribute('href'))
    
    Next_button = driver.find_elements(By.XPATH, '//span[@class="pagination-arrow-next"]')
    time.sleep(3)

# %%
print(len(Rent_url))
# Out:
# 330

# %%
Bed = []
Bath = []
Area = []
Price = []
Pets = []
Address =[]
Deposit = []
AC  = []
Dishwasher = []
Storage = []

# %%
for url in Rent_url:
    driver.get(url)
    delay = 3
    
    try:
        bed = driver.find_element(By.XPATH, '//*[@id="main-info"]/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[1]/div[2]/span[1]')
        Bed.append(bed.text)
    except NoSuchElementException:
        Bed.append('Null')
    except StaleElementReferenceException:
        Bed.append('Null')
    except WebDriverException:
        Bed.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        bath = driver.find_element(By.XPATH, '//span[@class="bathrooms"]')
        Bath.append(bath.text)
    except NoSuchElementException:
        Bath.append('Null')
    except StaleElementReferenceException:
        Bath.append('Null')
    except WebDriverException:
        Bath.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        area = driver.find_element(By.XPATH, '//div[@class="internals-item"][3]/div[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('Null')
    except StaleElementReferenceException:
        Area.append('Null')
    except WebDriverException:
        Area.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        price = driver.find_element(By.XPATH, '//div[@class="property-card-bottom-price"]/p')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Null')
    except StaleElementReferenceException:
        price.append('Null')
    except WebDriverException:
        price.append('Null')  
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        ac = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li[1]/div/span[2]')
        AC.append(ac.text)
    except NoSuchElementException:
        AC.append('Null')
    except WebDriverException:
        AC.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)

    try:
        dishwasher = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li[4]/div/span[2]')
        Dishwasher.append(dishwasher.text)
    except NoSuchElementException:
        Dishwasher.append('Null')
    except WebDriverException:
        Dishwasher.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except StaleElementReferenceException:
        Dishwasher.append('Null')

    
    try:
        address = driver.find_element(By.XPATH, '//span[@class="property-data-address-name"]')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Address.append('Null')
    except StaleElementReferenceException:
        Address.append('Null')
        
    try:
        pets = driver.find_element(By.XPATH, '//*[@id="main-info"]/section/div/div/rb-property-facilities/section/div[4]/span[2]')
        Pets.append(pets.text)
    except NoSuchElementException:
        Pets.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Pets.append('Null')
    except StaleElementReferenceException:
        Pets.append('Null')

# %%
DF4 = pd.DataFrame({'Address':Address,'Bed':Bed,'Bath':Bath,'Area':Area,'Pets':Pets,'Dishwasher':Dishwasher,'AC':AC,'Price':Price})
DF4
# Out:
#                                                Address     Bed Bath  \
# 0    Footscray, Paisley Street, Footscray VIC 3011,...      1    1
# 1                        Southbank VIC 3006, Australia      2    2
# 2                         Sorrento VIC 3943, Australia      3    3
# 3                        Southbank VIC 3006, Australia      3    2
# 4                         Sorrento VIC 3943, Australia      3    3
# ..                                                 ...     ...  ...
# 325                     Melbourne, Victoria, Australia  Studio   1
# 326                        Fingal, Victoria, Australia      3    3
# 327                            Rye VIC 3941, Australia      4    2
# 328  Toorak Accident Repair Centre, 718 Malvern Roa...      5    3
# 329  Madison Apartments, 39 Queen Street, Melbourne...  Studio   1
#
#               Area     Pets  Dishwasher                AC    Price
# 0      355 \nSq Ft  No pets        Null  Air Conditioning   $5,601
# 1       11 \nSq Ft  No pets  Dishwasher  Air Conditioning   $9,675
# 2             Null     Null  Dishwasher  Air Conditioning  $19,476
# 3      969 \nSq Ft  No pets     Parking  Air Conditioning  $13,196
# 4    1,808 \nSq Ft  No pets     Parking  Air Conditioning  $25,459
# ..             ...      ...         ...               ...      ...
# 325     11 \nSq Ft  No pets        Null  Air Conditioning   $5,771
# 326           Null     Null     Parking  Air Conditioning  $15,063
# 327           Null     Null        Null  Air Conditioning   $9,505
# 328  1,829 \nSq Ft  No pets     Parking  Air Conditioning  $23,974
# 329           Null     Null        Null         Furnished   $3,043
#
# [330 rows x 8 columns]

# %%
import time
import csv

# %%
csv_file_path = 'DF4.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file_path:
    csv_writer = csv.writer(csv_file_path)

# %%
import joblib
joblib.dump(DF4,'df4')
# Out:
# ['df4']

# %%
New_Data_Scraped =  joblib.load('df4')
New_Data_Scraped
# Out:
#                                                Address     Bed Bath  \
# 0    Footscray, Paisley Street, Footscray VIC 3011,...      1    1
# 1                        Southbank VIC 3006, Australia      2    2
# 2                         Sorrento VIC 3943, Australia      3    3
# 3                        Southbank VIC 3006, Australia      3    2
# 4                         Sorrento VIC 3943, Australia      3    3
# ..                                                 ...     ...  ...
# 325                     Melbourne, Victoria, Australia  Studio   1
# 326                        Fingal, Victoria, Australia      3    3
# 327                            Rye VIC 3941, Australia      4    2
# 328  Toorak Accident Repair Centre, 718 Malvern Roa...      5    3
# 329  Madison Apartments, 39 Queen Street, Melbourne...  Studio   1
#
#               Area     Pets  Dishwasher                AC    Price
# 0      355 \nSq Ft  No pets        Null  Air Conditioning   $5,601
# 1       11 \nSq Ft  No pets  Dishwasher  Air Conditioning   $9,675
# 2             Null     Null  Dishwasher  Air Conditioning  $19,476
# 3      969 \nSq Ft  No pets     Parking  Air Conditioning  $13,196
# 4    1,808 \nSq Ft  No pets     Parking  Air Conditioning  $25,459
# ..             ...      ...         ...               ...      ...
# 325     11 \nSq Ft  No pets        Null  Air Conditioning   $5,771
# 326           Null     Null     Parking  Air Conditioning  $15,063
# 327           Null     Null        Null  Air Conditioning   $9,505
# 328  1,829 \nSq Ft  No pets     Parking  Air Conditioning  $23,974
# 329           Null     Null        Null         Furnished   $3,043
#
# [330 rows x 8 columns]

# %%
New_Data_Scraped.to_excel("df4.xlsx", index = True, header = True)
print('spreadsheet saved :')
# Out:
# spreadsheet saved :

# %%
driver.close()
