# %%
from bs4 import BeautifulSoup
import selenium
from selenium.common.exceptions import TimeoutException
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, WebDriverException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://rentberry.com/nl/apartments/s/amsterdam-netherlands')
time.sleep(2)

# %%
consent = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/button[3]')
consent.click()

# %%
Rent_url = []
start = 0
end = 15
for page in range (start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="property-card-bottom-address__text link-ghost font-xs one-line-string"]')
    for i in url:
        Rent_url.append(i.get_attribute('href'))
    
    Next_button = driver.find_elements(By.XPATH, '//span[@class="pagination-arrow-next"]')
    time.sleep(3)

# %%
print(len(Rent_url))
# Out:
# 330

# %%
Bed = []
Bath = []
Area = []
Price = []
Pets = []
Address =[]
Deposit = []
AC  = []
Dishwasher = []
Storage = []

# %%
for url in Rent_url:
    driver.get(url)
    delay = 3
    
    try:
        bed = driver.find_element(By.XPATH, '//*[@id="main-info"]/rb-apartment-card-swiper/div/div[3]/rb-apartment-internals/section/div[1]/div[2]/span[1]')
        Bed.append(bed.text)
    except NoSuchElementException:
        Bed.append('Null')
    except StaleElementReferenceException:
        Bed.append('Null')
    except WebDriverException:
        Bed.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        bath = driver.find_element(By.XPATH, '//span[@class="bathrooms"]')
        Bath.append(bath.text)
    except NoSuchElementException:
        Bath.append('Null')
    except StaleElementReferenceException:
        Bath.append('Null')
    except WebDriverException:
        Bath.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        area = driver.find_element(By.XPATH, '//div[@class="internals-item"][3]/div[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('Null')
    except StaleElementReferenceException:
        Area.append('Null')
    except WebDriverException:
        Area.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        price = driver.find_element(By.XPATH, '//div[@class="property-card-bottom-price"]/p')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Null')
    except StaleElementReferenceException:
        price.append('Null')
    except WebDriverException:
        price.append('Null')  
    except TimeoutException as e:
        print('Exception Raise:', e)
    try:
        ac = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li/div/span[2]')
        AC.append(ac.text)
    except NoSuchElementException:
        AC.append('Null')
    except WebDriverException:
        AC.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)

    try:
        dishwasher = driver.find_element(By.XPATH, '//*[@id="property-amenities"]/div/div/div/rb-property-rb-amenities/div/rb-amenities/ul/li[2]/div/span[2]')
        Dishwasher.append(dishwasher.text)
    except NoSuchElementException:
        Dishwasher.append('Null')
    except WebDriverException:
        Dishwasher.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except StaleElementReferenceException:
        Dishwasher.append('Null')

    
    try:
        address = driver.find_element(By.XPATH, '//span[@class="property-data-address-name"]')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Address.append('Null')
    except StaleElementReferenceException:
        Address.append('Null')
        
    try:
        pets = driver.find_element(By.XPATH, '//*[@id="main-info"]/section/div/div/rb-property-facilities/section/div[4]/span[2]')
        Pets.append(pets.text)
    except NoSuchElementException:
        Pets.append('Null')
    except TimeoutException as e:
        print('Exception Raise:', e)
    except WebDriverException:
        Pets.append('Null')
    except StaleElementReferenceException:
        Pets.append('Null')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5112\3366126246.py in <module>
#       1 for url in Rent_url:
# ----> 2     driver.get(url)
#       3     delay = 3
#       4
#       5     try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     351     def get(self, url: str) -> None:
#     352         """Loads a web page in the current browser session."""
# --> 353         self.execute(Command.GET, {"url": url})
#     354
#     355     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: session deleted because of page crash
# from unknown error: cannot determine loading status
# from tab crashed
#   (Session info: chrome=121.0.6167.141)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF79E615E42+3538674]
# 	(No symbol) [0x00007FF79E234C02]
# 	(No symbol) [0x00007FF79E0E599D]
# 	(No symbol) [0x00007FF79E0D4294]
# 	(No symbol) [0x00007FF79E0D3CD3]
# 	(No symbol) [0x00007FF79E0D2EFC]
# 	(No symbol) [0x00007FF79E0D2E9F]
# 	(No symbol) [0x00007FF79E0D13A5]
# 	(No symbol) [0x00007FF79E0D1E5F]
# 	(No symbol) [0x00007FF79E0DF32E]
# 	(No symbol) [0x00007FF79E0F1D83]
# 	(No symbol) [0x00007FF79E0F61DA]
# 	(No symbol) [0x00007FF79E0D2420]
# 	(No symbol) [0x00007FF79E0F1953]
# 	(No symbol) [0x00007FF79E16C13E]
# 	(No symbol) [0x00007FF79E14EE53]
# 	(No symbol) [0x00007FF79E11F514]
# 	(No symbol) [0x00007FF79E120631]
# 	GetHandleVerifier [0x00007FF79E646CAD+3738973]
# 	GetHandleVerifier [0x00007FF79E69C506+4089270]
# 	GetHandleVerifier [0x00007FF79E694823+4057299]
# 	GetHandleVerifier [0x00007FF79E365C49+720121]
# 	(No symbol) [0x00007FF79E24126F]
# 	(No symbol) [0x00007FF79E23C304]
# 	(No symbol) [0x00007FF79E23C432]
# 	(No symbol) [0x00007FF79E22BD04]
# 	BaseThreadInitThunk [0x00007FFC791A257D+29]
# 	RtlUserThreadStart [0x00007FFC7ABEAA58+40]

# %%
DF10 = pd.DataFrame({'Address':Address,'Bed':Bed,'Bath':Bath,'Area':Area,'Pets':Pets,'Dishwasher':Dishwasher,'AC':AC,'Price':Price})
DF10
# Out:
#                                                Address   Bed  Bath  Area  \
# 0    9 Victoria Circus, Partickhill, Glasgow, G12 9...    2     2   Null
# 1    Burghead Drive, Linthouse, Glasgow, G51 4QQ, U...    2     1   Null
# 2    Barrland Street, Glasgow, G41 1BG, United Kingdom    2     2   Null
# 3    Rioja Finnieston, 1116 Argyle Street, Glasgow,...    4     1   Null
# 4    Jobcentre Plus, 20 Benalder Street, Partickhil...    2     2   Null
# ..                                                 ...   ...   ...   ...
# 260  Fox Street, Laurieston, Glasgow, G1 4AX, Unite...    3   Null  Null
# 261     Elliot Street, Glasgow, G3 8EX, United Kingdom    2   Null  Null
# 262  Blairatholl Gardens, Thornwood, Glasgow, G11 7...    2     1   Null
# 263  24 Belmont Street, Glasgow, G12 8EW, United Ki...    2     1   Null
# 264  9 Victoria Circus, Partickhill, Glasgow, G12 9...  Null    2   Null
#
#      Pets Dishwasher         AC   Price
# 0    Null       Null  Furnished  £1,396
# 1    Null       Null       Null    £795
# 2    Null       Null       Null  £1,250
# 3    Null       Null  Furnished  £1,708
# 4    Null       Null       Null  £1,401
# ..    ...        ...        ...     ...
# 260  Null       Null       Null  £1,876
# 261  Null       Null       Null  £1,400
# 262  Null       Null       Null  £1,200
# 263  Null       Null       Null  £1,301
# 264  Null       Null  Furnished  £1,396
#
# [265 rows x 8 columns]

# %%
import time
import csv

# %%
csv_file_path = 'DF10.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file_path:
    csv_writer = csv.writer(csv_file_path)

# %%
import joblib
joblib.dump(DF10,'df10')
# Out:
# ['df10']

# %%
New_Data_Scraped7 =  joblib.load('df10')
New_Data_Scraped7
# Out:
#                                                Address   Bed  Bath  Area  \
# 0    9 Victoria Circus, Partickhill, Glasgow, G12 9...    2     2   Null
# 1    Burghead Drive, Linthouse, Glasgow, G51 4QQ, U...    2     1   Null
# 2    Barrland Street, Glasgow, G41 1BG, United Kingdom    2     2   Null
# 3    Rioja Finnieston, 1116 Argyle Street, Glasgow,...    4     1   Null
# 4    Jobcentre Plus, 20 Benalder Street, Partickhil...    2     2   Null
# ..                                                 ...   ...   ...   ...
# 260  Fox Street, Laurieston, Glasgow, G1 4AX, Unite...    3   Null  Null
# 261     Elliot Street, Glasgow, G3 8EX, United Kingdom    2   Null  Null
# 262  Blairatholl Gardens, Thornwood, Glasgow, G11 7...    2     1   Null
# 263  24 Belmont Street, Glasgow, G12 8EW, United Ki...    2     1   Null
# 264  9 Victoria Circus, Partickhill, Glasgow, G12 9...  Null    2   Null
#
#      Pets Dishwasher         AC   Price
# 0    Null       Null  Furnished  £1,396
# 1    Null       Null       Null    £795
# 2    Null       Null       Null  £1,250
# 3    Null       Null  Furnished  £1,708
# 4    Null       Null       Null  £1,401
# ..    ...        ...        ...     ...
# 260  Null       Null       Null  £1,876
# 261  Null       Null       Null  £1,400
# 262  Null       Null       Null  £1,200
# 263  Null       Null       Null  £1,301
# 264  Null       Null  Furnished  £1,396
#
# [265 rows x 8 columns]

# %%
New_Data_Scraped7.to_excel("df10.xlsx", index = True, header = True)
print('spreadsheet saved :')
# Out:
# spreadsheet saved :
